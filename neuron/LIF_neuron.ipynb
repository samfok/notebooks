# %% [markdown]
# # Notebook description

# %% [markdown]
# This notebook examines the statistics of an leaky integrate and fire (LIF) neuron when provided Poisson spikes as input and measuring the neuron's output spikes using a synaptic filter.
#
# We would specifically like to know:
#  - How does the LIF tuning curve change with synaptic noise at its input?
#  - How noisy is the output of an LIF neuron?

# %% [markdown]
# # Summary of results

# %% [markdown]
#  - Synaptic input noise causes the LIF tuning curve to turn on at mean input levels below threshold
#  - Synaptic input noise causes the LIF tuning curve to undershoot the theoretical LIF tuning curve above threshold
#  - The LIF neuron fires apporximately uniformly regardless of its input noise

# %% [markdown]
# # Theoretical LIF neuron analysis

# %% [markdown]
# An LIF neuron is so named because of its dynamics and spiking (firing) mechanism.
#
# The dynamics of the LIF neuron are goverened by
#
# $$\tau\dot{x}=-x+u$$
#
# where
#  - $x$ is the neuron state
#  - $\tau$ is the membrane time constant and
#  - $u$ is the input to the neuron
#
# The neuron dynamics has two terms: $-x$, and $u$. $-x$ is the leaky component of the integrator and $u$ is the input being integrated. The speed of the neuron dynamics is governed by $\tau$. $u$ can either be controlled directly as an input current or set as the scaled output of a synapse. If $u$ is derived from a synapse, $u=\alpha x_{syn}$, where $x_{syn}$ is the synaptic state and $\alpha$ scales the synaptic output.
#
# The firing mechanism is governed by
#
# $$
# x\ge x_t \rightarrow
#   \begin{cases}
#     \text{soma outputs a spike} \\
#     x:=0 & t_{spk}\le t < t_{spk}+t_{ref}\\
#   \end{cases}
# $$
#
# where
#  - $x_t$ is the threshold
#  - $t_{spk}$ is the time at which $x(t)$ crosses threshold and
#  - $t_{ref}$ is the refractory period
#
# That is, when $x$ reaches the threshold $x_{t}$, we declare the neuron as having spiked, and reset and hold $x$ to $0$ for a refactory period $t_{ref}$.

# %% [markdown]
# Assuming that the input $u$ is constant, we can derive the output spike rate of an LIF neuron analytically. Our approach is to find the time it takes for the neuron to reach threshold, $t_t$, and then substituting that time into the equation describing the firing rate. The firing rate equation is
#
# $$f=\frac{1}{t_{ref}+t_t}$$
#
# Integrating the dynamics equation,
#
# \begin{align}
# \tau\frac{dx}{dt} &= -x + u \\
# \frac{\tau}{-x+u}dx &= dt \\
# \int_{x_0}^{x}\frac{\tau}{-x+u}dx &= \int_{0}^{t} dt & \text{with $x(0)=x_0$}\\
# \tau\int_{x_0}^{x}\frac{1}{-x+u}dx &= \int_{0}^{t} dt. \\
# \end{align}
#
# Substituting $v=-x+u$ (so $-dv=dx$),
#
# \begin{align}
# -\tau\int\frac{1}{v}dv &= \int_{0}^{t} dt \\
# -\tau[\ln(v)]_{v_0}^{v} &= t \\
# -\tau[\ln(-x+u)]_{x_0}^{x} &= t \\
# -\tau[\ln(-x+u)-\ln(-x_0+u)] &= t \\
# -\tau\ln\left(\frac{-x+u}{-x_0+u}\right) &= t. \\
# \end{align}
#
# Setting $t=t_t$ when $x=x_t$, we have
#
# $$
# -\tau\ln\left(\frac{-x_t+u}{-x_0+u}\right) = t_t,
# $$
#
# so the firing rate for an LIF neuron with constant input will be
#
# $$
# f = \frac{1}{t_{ref}-\tau\ln\left(\frac{u-x_t}{u-x_0}\right)} \qquad u>x_t
# $$
#
# If we set $x_0=0$, we have the firing rate function typically seen in the literature,
#
# $$
# f = \frac{1}{t_{ref}-\tau\ln\left(1-\frac{x_t}{u}\right)} \qquad u>x_t
# $$
#
# As an aside, solving for $x$ in terms of $t$,
#
# \begin{align}
# -\tau\ln\left(\frac{-x+u}{-x_0+u}\right) &= t \\
# \frac{-x+u}{-x_0+u} &= e^{-t/\tau} \\
# -x+u &= (-x_0+u)e^{-t/\tau} \\
# x &= -(-x_0+u)e^{-t/\tau} + u \\
# x &= x_0e^{-t/\tau}+(1-e^{-t/\tau})u \\
# \end{align}
#
# we can see that $x(t)$ is composed of a decaying initial condition term and a term that exponentially approahces the input.

# %% [markdown]
# ## Model and function definitions

# %% [markdown]
# Lots of code in this section to setup the simulations. Only necessary if you're interested in the simulation implementation.

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# import libraries
FIGDIR = './figures/'
from utils.data import checkdir
checkdir(FIGDIR)

import numpy as np
s = random.seed(2)
rng = random.RandomState(s)
from utils.signal import make_poisson_spikes, filter_spikes

from utils.neuron import th_lif_fi, run_lifsoma, taylor1_lif_fi, taylor1log_lif_fi

import multiprocessing
from utils.plot import (
    plot_continuous, plot_spike_raster, plot_histogram,
    plot_contour, plot_scatter, match_xlims, save_close_fig)
plot_filtered_spikes = plot_continuous
plot_tuning_curve = plot_continuous

# %%
# define some mathematically useful functions
from scipy.special import erf
def normal_cdf(x, mu=0., sigma=1.):
    return 1./2.*(1+erf((x-mu)/(sigma*np.sqrt(2))))

s1_percentiles = [normal_cdf(-1.)*100., normal_cdf(1.)*100.] # Gaussian 1 sigma percentiles
def th_u_xmin(lam, tau):
    """Theoretical steady state xmin for uniform input"""
    ret = np.zeros(len(lam))
    idx = lam > 0
    ret[idx] = np.exp(-1./(lam[idx]*tau))/(tau*(1.-np.exp(-1./(lam[idx]*tau))))
    return ret


def th_u_xmax(lam, tau):
    """Theoretical steady state xmax for uniform input"""    
    ret = np.zeros(len(lam))
    idx = lam > 0
    ret[idx] = 1./(tau*(1.-np.exp(-1./(lam[idx]*tau))))
    return ret

# %%
# Define a class for collecting output statistics
# from an LIF neuron given Poisson spiking input

def _set_io_collector(*args):
    global io_collector
    io_collector = args[0]

def _call_compute_stats(fexc_finh):
    """for using multiprocessing with a class method"""
    return io_collector._compute_stats(fexc_finh)

class LIF_IO_Collector(object):
    def __init__(self, dt, T, alpha, neuronp, filt_tau, k_trans, dev_pcts=s1_percentiles):
        self.dt = dt
        self.T = T
        self.alpha = alpha
        self.neuronp = neuronp
        self.filt_tau = filt_tau
        self.k_trans = k_trans
        self.nsteps = int(np.ceil(T/dt))
        self.dev_pcts = dev_pcts
    
    def _compute_stats(self, fexc_finh):
        fexc = fexc_finh[0]
        finh = fexc_finh[1]
        
        fexc_nspikes = 2.*self.T*fexc
        finh_nspikes = 2.*self.T*finh
        fexc_spks_in = make_poisson_spikes(fexc, fexc_nspikes, rng)
        finh_spks_in = make_poisson_spikes(finh, finh_nspikes, rng)
        t, fexc_in = filter_spikes(self.dt, self.T, fexc_spks_in, self.neuronp['tau_syn'])
        t, finh_in = filter_spikes(self.dt, self.T, finh_spks_in, self.neuronp['tau_syn'])

        u_in = self.alpha*(fexc_in - finh_in)
        spk_t = run_lifsoma(self.dt, u_in, self.neuronp['tau_m'], self.neuronp['tref'], self.neuronp['xt'])
        t, rate_out = filter_spikes(self.dt, self.T, spk_t, self.filt_tau)

        ss_idx = t>self.k_trans*self.neuronp['tau_syn']
        tuning = np.mean(rate_out[ss_idx])
        pct_obs = np.percentile(rate_out[ss_idx], self.dev_pcts)
        dev1s_l = tuning-pct_obs[0]
        dev1s_u = pct_obs[1]-tuning
        
        return [tuning, dev1s_l, dev1s_u]
    
    def collect_io_stats(self, fexc, finh=None, ret_devs=False, max_proc=1):
        shape = fexc.shape
        fexc = fexc.flatten()
        if finh is not None:
            finh = finh.flatten()
            assert fexc.shape == finh.shape
        else:
            finh = np.zeros(fexc.shape)

        tuning = np.zeros(fexc.shape)
        dev1s_l = np.zeros(fexc.shape)
        dev1s_u = np.zeros(fexc.shape)

        fexc.shape = -1,1
        finh.shape = -1,1
        fexc_finh = np.hstack((fexc, finh))
        
        n_proc = min(fexc.shape[0], multiprocessing.cpu_count()-1)
        if max_proc is not None:
            n_proc = min(n_proc, max_proc) 
        
        if n_proc == 1:
            results = map(self._compute_stats, fexc_finh)
        else:
            worker_pool = multiprocessing.Pool(processes=n_proc, initializer=_set_io_collector, initargs=(self,))
            results = worker_pool.map(_call_compute_stats, fexc_finh)
            worker_pool.close()
            worker_pool.join()

        for idx, result in enumerate(results):
            tuning[idx] = result[0]
            dev1s_l[idx] = result[1]
            dev1s_u[idx] = result[2]
        
        tuning = tuning.reshape(shape)
        dev1s_l = dev1s_l.reshape(shape)
        dev1s_u = dev1s_u.reshape(shape)

        if ret_devs:
            retval = tuning, dev1s_l, dev1s_u
        else:
            retval = tuning
        return retval

# %%
# define a function for sweeping the input space of 
# an LIF neuron and measuring its output statistics

def fexc_finh_sweep(neuronp, filt_tau=.01, k_trans=5, max_u=6., max_f=1000., npts=10, fname_pre='', max_proc=None, close=False):
    alpha = max_u/max_f

    fexc = np.linspace(0, max_f, npts)
    finh = np.linspace(0, max_f, npts)
    fexc_g, finh_g = np.meshgrid(fexc, finh)
    lam_g = fexc_g+finh_g
    u_g = alpha*(fexc_g-finh_g)
    s_g = np.sqrt(lam_g/(2.*neuronp['tau_syn']))
    tuning_th = th_lif_fi(u_g, neuronp['tau_m'], neuronp['tref'], neuronp['xt'])

    T = 2.
    dt = .0001

    io_collector = LIF_IO_Collector(dt=dt, T=T, alpha=alpha, neuronp=neuronp, filt_tau=filt_tau, k_trans=k_trans)
    tuning, dev1s_l, dev1s_u = io_collector.collect_io_stats(fexc=fexc_g, finh=finh_g, ret_devs=True, max_proc=max_proc)

    # E[u]
    fig, ax = plot_contour(fexc_g, finh_g, u_g, contourfp={'cmap':plt.cm.BrBG}, contourp={'colors':'r'},
                           figp={'figsize':(8,6)},
                           xlabel=r'$f_{exc}$', xlabelp={'fontsize':20}, ylabel=r'$f_{inh}$', ylabelp={'fontsize':20},
                           title=r'$E[u]$', titlep={'fontsize':20})
    plot_scatter(fexc_g, finh_g, scatterp={'c':'m', 'marker':'+', 'alpha':.5}, ax=ax, 
                 xlim=(fexc[0], fexc[-1]), ylim=(finh[0], finh[-1]), close=close,
                 fname=FIGDIR+fname_pre+'fe_fi_u.png', savep={'dpi':200})

    # a(E[u]))
    fig, ax = plot_contour(fexc_g, finh_g, tuning_th, contourfp={'cmap':plt.cm.copper}, contourp={'colors':'r'},
                           figp={'figsize':(8,6)},
                           xlabel=r'$f_{exc}$', xlabelp={'fontsize':20}, ylabel=r'$f_{inh}$', ylabelp={'fontsize':20},
                           title=r'$a(E[u])$', titlep={'fontsize':20})
    plot_scatter(fexc_g, finh_g, scatterp={'c':'m', 'marker':'+', 'alpha':.5}, ax=ax, 
                 xlim=(fexc[0], fexc[-1]), ylim=(finh[0], finh[-1]), close=close,
                 fname=FIGDIR+fname_pre+'fe_fi_tuning_th.png', savep={'dpi':200})

    # sqrt(Var(u))
    fig, ax = plot_contour(fexc_g, finh_g, s_g, contourfp={'cmap':plt.cm.PuOr}, contourp={'colors':'r'},
                           figp={'figsize':(8,6)},
                           xlabel=r'$f_{exc}$', xlabelp={'fontsize':20}, ylabel=r'$f_{inh}$', ylabelp={'fontsize':20},
                           title=r'$\sigma(f_{exc}+f_{inh})$', titlep={'fontsize':20})
    plot_scatter(fexc_g, finh_g, scatterp={'c':'m', 'marker':'+', 'alpha':.5}, ax=ax, 
                 xlim=(fexc[0], fexc[-1]), ylim=(finh[0], finh[-1]), close=close,
                 fname=FIGDIR+fname_pre+'fe_fi_noise.png', savep={'dpi':200})

    # E[a(u)]
    fig, ax = plot_contour(fexc_g, finh_g, tuning, contourfp={'cmap':plt.cm.copper}, contourp={'colors':'r'},
                           figp={'figsize':(8,6)},
                           xlabel=r'$f_{exc}$', xlabelp={'fontsize':20}, ylabel=r'$f_{inh}$', ylabelp={'fontsize':20},
                           title=r'$E[a(u)]$', titlep={'fontsize':20})
    plot_scatter(fexc_g, finh_g, scatterp={'c':'m', 'marker':'+', 'alpha':.5}, ax=ax, 
                 xlim=(fexc[0], fexc[-1]), ylim=(finh[0], finh[-1]), close=close,
                 fname=FIGDIR+fname_pre+'fe_fi_noisy_tuning.png', savep={'dpi':200})

    # Var(a(u))
    fig, ax = plot_contour(fexc_g, finh_g, dev1s_l, contourfp={'cmap':plt.cm.winter}, contourp={'colors':'r'},
                           subplotp=(1,2,1), figp={'figsize':(16,6)},
                           xlabel=r'$f_{exc}$', xlabelp={'fontsize':20}, ylabel=r'$f_{inh}$', ylabelp={'fontsize':20},
                           title=r'$-\sigma\%(a(u))$', titlep={'fontsize':20})
    plot_scatter(fexc_g, finh_g, scatterp={'c':'m', 'marker':'+', 'alpha':.5}, ax=ax, 
                 xlim=(fexc[0], fexc[-1]), ylim=(finh[0], finh[-1]))
    fig, ax = plot_contour(fexc_g, finh_g, dev1s_u, contourfp={'cmap':plt.cm.winter}, contourp={'colors':'r'}, fig=fig,
                           subplotp=(1,2,2),
                           xlabel=r'$f_{exc}$', xlabelp={'fontsize':20}, ylabel=r'$f_{inh}$', ylabelp={'fontsize':20},
                           title=r'$+\sigma\%(a(u))$', titlep={'fontsize':20})
    plot_scatter(fexc_g, finh_g, scatterp={'c':'m', 'marker':'+', 'alpha':.5}, ax=ax, 
                 xlim=(fexc[0], fexc[-1]), ylim=(finh[0], finh[-1]), close=close,
                 fname=FIGDIR+fname_pre+'fe_fi_noisy_tuning.png', savep={'dpi':200});

# %%
# Define a class for collecting the synapse, soma, and filtered output
# statistics of an LIF neuron given Poisson spiking input

OUTSTATSDIR = 'lif_outstats/'
checkdir(FIGDIR+OUTSTATSDIR)

def _worker_init(dt_init, alpha_init, xlim_T_init, fname_init, close_init, tgt_outspikes_init, neuronp_init):
    # these globals only contained within each worker
    global dt, alpha, xlim_T, fname, close, tgt_outspikes
    global tau_syn, tau_m, tref, xt
    dt = dt_init
    alpha = alpha_init
    xlim_T = xlim_T_init
    fname = fname_init
    close = close_init
    tgt_outspikes= tgt_outspikes_init
    tau_syn = neuronp_init['tau_syn']
    tau_m = neuronp_init['tau_m']
    tref = neuronp_init['tref']
    xt = neuronp_init['xt']

def _worker_lif_stats(uf):
    u = uf[0]
    rate = uf[1]
    
    fig = figure(figsize=(16,6))
    ax = [fig.add_subplot(4,2,1)]
    for i in xrange(1,4):
       ax.append(fig.add_subplot(4,2,i*2+1))

    th_f = th_lif_fi(u, tau_m, tref, xt)
    T = 1.
    if th_f > 0:
        T = max(T, tgt_outspikes/th_f)
    nsteps = int(np.ceil(T/dt))

    nspikes = max(10, 2.*T*rate)
    spks_in = make_poisson_spikes(rate, nspikes, rng)
    plot_spike_raster(spks_in, ax=ax[0], yticks=[])

    t, u_in = filter_spikes(dt, T, spks_in, tau_syn)
    u_in *= alpha
    mean_uin = np.mean(u_in[t>5*tau_syn])
    plot_continuous(t, u_in, ax=ax[1], 
                    axhline=mean_uin, axhlinep={'color':'r'},
                    ylabel='syn', ylabelp={'fontsize':16})

    spk_t, state = run_lifsoma(dt, u_in, tau_m, tref, xt, ret_state=True)
    plot_continuous(t, state, ax=ax[2], ylabel='soma', ylabelp={'fontsize':16})

    t, rate_out = filter_spikes(dt, xlim_T, spk_t, tau_syn)
    ss_idx = t>5*tau_syn
    mean_rate_out = np.mean(rate_out[ss_idx])
    var_rate_out = np.var(rate_out[ss_idx])
    plot_continuous(t, rate_out, ax=ax[3], 
                    axhline=mean_rate_out, axhlinep={'color':'r'},
                    xlabel=r'$t$ (s)', xlabelp={'fontsize':20},
                    ylabel=r'filtered out', ylabelp={'fontsize':16})
    ax[3].axhline(th_f, color='r', linestyle=':')

    for a in ax[:-1]:
        setp(a.get_xticklabels(), visible=False)
    match_xlims(ax, (0, xlim_T))
    ax[0].set_title(r'$\alpha=%.1e$,  $E[u]=%.2f$,  $f_{in}=%.1f$ Hz' % (alpha, u, rate), fontsize=20)

    if len(spk_t) > 5:
        ax = fig.add_subplot(1,2,2)
        isi = np.diff(spk_t)
        histp = dict(bins=int(tgt_outspikes/10), normed=True, histtype='step')
        plot_histogram(isi, histp=histp, ax=ax,
                       axvline=1./mean_rate_out, axvlinep={'color':'r', 'label':'observed mean'},
                       xlabel='output isi (s)', xlabelp={'fontsize':20}, 
                       xlim=(min(isi), max(isi)),
                       title=r'$%d$ spikes, $E[a(u)]=%.1f$, $Var(a(u))=%.1f$' % (len(spk_t), mean_rate_out, var_rate_out), 
                       titlep={'fontsize':20})
        if th_f > 0:
            ax.axvline(1./th_f, color='r', linestyle=':', label='theoretical mean')
        ax.legend(loc='upper right')
    sub_fname = fname
    if fname is not None:
        sub_fname = fname + '_alpha%.1e_u%.2f_f%.1f_.png' % (alpha, u, rate)
    save_close_fig(fig, sub_fname, close)


def lif_stats(u, dt=.0001, max_f=1000., xlim_T=1., fname=None, close=False, tgt_outspikes=1000, max_processes=None):
    neuronp=dict(tau_syn=.01, tau_m=.01, tref=.005, xt=1.)

    max_u = max(u)

    alpha = max_u/max_f
    f = u/alpha
    
    n_processes = min(len(u), multiprocessing.cpu_count()-1)
    if max_processes is not None:
        n_processes = min(n_processes, max_processes)

    worker_init_args = (dt, alpha, xlim_T, fname, close, tgt_outspikes, neuronp)
    
    if n_processes == 1:
        _worker_init(*worker_init_args)
        map(_worker_lif_outstats, zip(u,f))
    else:
        worker_pool = multiprocessing.Pool(processes=n_processes, initializer=_worker_init, initargs=worker_init_args)
        worker_pool.map(_worker_lif_stats, zip(u, f))
        worker_pool.close()
        worker_pool.join()

# %% [markdown]
# # LIF with noisy synaptic input

# %% [markdown]
# We'll start by showing the LIF neuron under constant input

# %%
# create plots for soma
T = .1
dt = .0001
tau_m = .01
tref = .005
xt = 1.

# fi curve
u = np.linspace(0, 10, 100)
fi = th_lif_fi(u, tau_m, tref, xt)
plot_tuning_curve(u, fi, plotp={'color':'k','linewidth':2}, figp={'figsize':(8,6)},
                  xlabel=r'$u$',xlabelp={'fontsize':20},
                  ylabel=r'$a(u)$ (spikes per second)', ylabelp={'fontsize':20},
                  title='Theoretical LIF neuron tuning curve', titlep={'fontsize':20})

# timeseries for a constant input
u_val = 1.05
nsteps = int(np.ceil(T/dt))
t = np.arange(nsteps)*dt
u = np.zeros(nsteps)+u_val
spk_times, x = run_lifsoma(dt, u, tau_m, tref, xt, ret_state=True)

fig, ax = plot_continuous(t, x, plotp={'color':'b','linewidth':2}, figp={'figsize':(8,6)}, yticks = [1],
                          axhline=u_val, axhlinep={'color':'r', 'linestyle':':', 'label':'input'},
                          xlabel=r'$t$ (s)', xlabelp={'fontsize':20},
                          ylabel=r'$x$', ylabelp={'fontsize':24},
                          title='Given a constant input, the LIF neuron\napproaches the input and spikes uniformly\n',
                          titlep={'fontsize':20})
ax.set_yticklabels([r'$x_t$'])
ax.tick_params('y', labelsize=20)
markerline, stemlines, baseline = ax.stem(spk_times, np.zeros(spk_times.shape[0])+1.2, markerfmt='')
setp(stemlines, 'linewidth', 2);

# %% [markdown]
# However, a neuron with a synapse has a spiking input rather than constant current input. By virtue of having of spiking input at its synapse, the input current seen by the neuron's soma is noisy as seen in this demo [notebook](http://nbviewer.ipython.org/github/fragapanagos/notebooks/blob/master/synapse/synapse_demo.ipynb). Next we demonstrate that a noisy spiking input changes the LIF tuning curve.
#
# For input spike rate $f_{exc}$ and synaptic input current scaling factor $\alpha$,
#
# \begin{align}
# E[u]& = \alpha E[x_{syn}] \\
#  &= \alpha f_{exc}
# \end{align}
#
# This holds regardless of whether the input spikes are Poisson, uniform, or anything in between. However, the spread of the input current does depends on the statistics of the input spikes.

# %%
# Spike noise in noisy out LIF neuron
tau_syn = .01
tau_m = .01
filt_tau = tau_syn

tref = .005
xt = 1.
k_trans = 5 # number of tau_syn to wait before collecting rate data

dt = .0001
T = 2. + k_trans*tau_syn
T_ss = T - k_trans*tau_syn

max_u = 6.
max_f = 1000.

nsamples = 20
# fi curve
u_th = np.sort(np.linspace(0, max_u, 2*nsamples).tolist() + [xt])
fi = th_lif_fi(u_th, tau_m, tref, xt)
fig, ax = plot_tuning_curve(u_th, fi, plotp={'color':'b','linewidth':2, 'label':'$a(E[u])$'}, 
                            figp={'figsize':(8,6), },
                            xlabelp={'xlabel':r'$u$', 'fontsize':20}, 
                            ylabelp={'ylabel':r'$a(u)$', 'fontsize':20})
fig.subplots_adjust(hspace=1.)
u = np.linspace(0, max_u, nsamples)
alpha = max_u/max_f
f = u/alpha

neuronp = dict(tau_syn=tau_syn, tau_m=tau_m, tref=tref, xt=xt)
io_collector = LIF_IO_Collector(dt, T, alpha, neuronp, filt_tau=filt_tau, k_trans=k_trans, dev_pcts=[5,95])
tuning, dev_l, dev_u = io_collector.collect_io_stats(fexc=f, finh=None, ret_devs=True, max_proc=None)

xmin_th = th_u_xmin(tuning, filt_tau)
xmax_th = th_u_xmax(tuning, filt_tau)
xmin_dev_th = (tuning-xmin_th).reshape((1, -1))
xmax_dev_th = (xmax_th-tuning).reshape((1, -1))
xmin_xmax_dev_th = np.vstack((xmin_dev_th, xmax_dev_th))

yerr = np.vstack((dev_l.reshape((1, -1)), dev_u.reshape((1, -1))))
ax.plot(u, tuning, 'r-o', label=r'$E[a(u)]$')
ax.errorbar(u, tuning, yerr=yerr, fmt='r')
eb = ax.errorbar(u, tuning, yerr=xmin_xmax_dev_th, fmt='none', ecolor='k')
eb[-1][0].set_linestyle(':')
eb[-1][0].set_label('min/max bounds for uniform spikes')
ax.legend(loc='upper left')
nsteps_ss = int(np.ceil(T_ss/dt))
ax.set_title('The tuning curve changes with input synaptic Poisson spiking noise\n' +
             r'$%d$ samples over $%d\tau_{syn}$ , ' % (nsteps_ss, int(np.round(T_ss/tau_syn))) +
             r'$f_{max}\tau_{syn}=%.1f$' % (max_f*tau_syn),
             fontsize=20, y=1.03);
ax.set_xlabel(r'$E[u]$', fontsize=20)
ax.set_ylabel('spikes per second', fontsize=20)
fig.savefig(FIGDIR+'syn_lif_syn.png', dpi=200)

fig = figure(figsize=(8,6))
ax = fig.add_subplot(111)
eb = ax.errorbar(u, np.zeros(u.shape), yerr=xmin_xmax_dev_th, fmt='none', ecolor='k')
eb[-1][0].set_linestyle(':')
eb[-1][0].set_label('min/max bounds for uniform spikes')
ax.errorbar(u, np.zeros(u.shape), yerr=yerr, fmt='ro')
ax.legend(loc='upper right')
ax.set_title("The $5/95\%$ errorbars suggest that \nLIF neuron fires uniformly above threshold", fontsize=20)
ax.set_ylabel(r'$a(u)-E[a(u)]$' + '\n(spikes per second)', fontsize=20)
ax.set_xlabel(r'$E[u]$', fontsize=20)
fig.savefig(FIGDIR+'syn_lif_syn_noise.png', dpi=200)

# %% [markdown]
# As the errorbar plot suggests, the LIF neuron still fires relatively uniformly when significantly above threshold despite the fact that its input derived from noisy Poisson spikes.
#
# We can maintain the same expected input current while varying the noise level by adding an inhibitory spike train and controlling the relative frequency between the excitatory and inhibitory spikes. With inhibitory spikes arriving at rate $f_{inh}$,
#
# $$
# E[u] = \alpha(f_{exc}-f_{inh})
# $$
#
# Now the input current is the scaleed difference between the excitatory and input spike trains.

# %%
neuronp = dict(tau_syn=.01, tau_m=.01, tref=.005, xt=1.)

max_u = 6.
max_f = 1000.
fname_pre = 'max_u%.1f_max_f%d_' % (max_u, int(max_f))
fexc_finh_sweep(neuronp, filt_tau=.01, k_trans=5, max_u=max_u, max_f=max_f, npts=20, fname_pre=fname_pre, close=True)

max_u = 12.
max_f = 2000.
fname_pre = 'max_u%.1f_max_f%d_' % (max_u, int(max_f))
fexc_finh_sweep(neuronp, filt_tau=.01, k_trans=5, max_u=max_u, max_f=max_f, npts=20, fname_pre=fname_pre)

max_u = 6.
max_f = 2000.
fname_pre = 'max_u%.1f_max_f%d_' % (max_u, int(max_f))
fexc_finh_sweep(neuronp, filt_tau=.01, k_trans=5, max_u=max_u, max_f=max_f, npts=20, fname_pre=fname_pre, close=True)

# %% [markdown]
# As in the case with only excitatory input, we see that the tuning curve with noisy excitatory and inhibitory input deviates from the theoretical tuning curve with constant excitatory and inhibitory inputs. We also see that the noise of the neuron's output increases with the common mode (looking from bottom left to upper right on the $\pm\sigma\%(a(u))$ plots). For a fixed common and increasing neuron firing rate, the noise of the neuron's output settles like a uniform spiking rate (looking from upper left to bottom right on the $\pm\sigma\%(a(u))$ plots).

# %%
# Collect the timeseries data for an LIF neuron
u = np.linspace(.1, 6, 9)
lif_stats(u, max_f=100., fname=FIGDIR+OUTSTATSDIR+'lif_inout_stats', close=True, tgt_outspikes=1000, max_processes=None)
lif_stats(u, max_f=1000., fname=FIGDIR+OUTSTATSDIR+'lif_inout_stats', close=False, tgt_outspikes=1000, max_processes=None)
lif_stats(u, max_f=10000., fname=FIGDIR+OUTSTATSDIR+'lif_inout_stats', close=True, tgt_outspikes=1000, max_processes=None)

# %% [markdown]
# # Appendix

# %% [markdown]
# ## Rearranging the LIF firing rate equation for input

# %% [markdown]
# Sometimes it's useful to determine the input required to produce a given output firing rate.
#
# \begin{align}
# f &= \frac{1}{t_{ref}-\tau\ln\left(1-\frac{x_t}{u}\right)} & u>x_t \\
# t_{ref}-\tau\ln\left(1-\frac{x_t}{u}\right) &= \frac{1}{f} \\
# \tau\ln\left(1-\frac{x_t}{u}\right) &= t_{ref}-\frac{1}{f} \\
# \ln\left(1-\frac{x_t}{u}\right) &= (t_{ref}-1/f)/\tau \\
# 1-\frac{x_t}{u} &= e^{(t_{ref}-1/f)/\tau} \\
# \frac{x_t}{u} &= 1-e^{(t_{ref}-1/f)/\tau} \\
# u &= \frac{x_t}{1-e^{(t_{ref}-1/f)/\tau}} \\
# \end{align}

# %% [markdown]
# ## Linear approximation of the LIF firing rate equation

# %% [markdown]
# We can linearly approximate the LIF firing rate equation when $u>x_t$ and $u\approx a$ using the Taylor series expansion
#
# \begin{align}
# f(u; a) &\approx f(a) + f'(a)(u-a) & \text{first order Taylor series expansion}\\
#  &= \frac{1}{t_{ref}-\tau\ln\left(1-\frac{x_t}{a}\right)} +
#     \left(\frac{-1}{\left(t_{ref}-\tau\ln\left(1-\frac{x_t}{a}\right)\right)^2}\frac{-\tau}{1-\frac{x_t}{a}}\frac{x_t}{a^2}\right)(u-a)
#      & \text{lots of chain rule} \\
#  &= \frac{1}{t_{ref}-\tau\ln\left(1-\frac{x_t}{a}\right)} +
#     \left(\frac{1}{\left(t_{ref}-\tau\ln\left(1-\frac{x_t}{a}\right)\right)^2}\frac{\tau x_t}{a(a-x_t)}\right)(u-a)  \\
#  &= \frac{1}{t_{ref}-\tau\ln\left(1-\frac{x_t}{a}\right)} +
#     \frac{\tau x_t}{\left(t_{ref}-\tau\ln\left(1-\frac{x_t}{a}\right)\right)^2a(a-x_t)}(u-a)  \\
#  &= k_0 + k_1u
# \end{align}
#
# where
#
# \begin{align}
# k_0 &= \frac{1}{t_{ref}-\tau\ln\left(1-\frac{x_t}{a}\right)} - k_1a\\
# k_1 &= \frac{\tau x_t}{\left(t_{ref}-\tau\ln\left(1-\frac{x_t}{a}\right)\right)^2a(a-x_t)} \\
# \end{align}
#
# Expanding the chain rule application,
#
# \begin{align}
# \frac{d}{du}f(u) &= \frac{-1}{\left(t_{ref}-\tau\ln\left(1-\frac{x_t}{u}\right)\right)^2}
#     \frac{d}{du}\left(t_{ref}-\tau\ln\left(1-\frac{x_t}{u}\right)\right) \\
#  &= \frac{-1}{\left(t_{ref}-\tau\ln\left(1-\frac{x_t}{u}\right)\right)^2}
#     \frac{-\tau}{\left(1-\frac{x_t}{u}\right)}
#     \frac{d}{du}\left(1-\frac{x_t}{u}\right) \\
# &= \frac{-1}{\left(t_{ref}-\tau\ln\left(1-\frac{x_t}{u}\right)\right)^2}
#     \frac{-\tau}{\left(1-\frac{x_t}{u}\right)}
#     \frac{x_t}{u^2} \\
# \end{align}

# %%
dt = .0001
tau_m = .01
tref = .005
xt = 1.

# fi curve
u = np.linspace(0, 10, 100)
fi = th_lif_fi(u, tau_m, tref, xt)
fig, ax = plot_continuous(u, fi, plotp={'color':'k','linewidth':2}, figp={'figsize':(8,6)},
                          xlabel=r'$u$',xlabelp={'fontsize':20},
                          ylabel=r'$a(u)$ (spikes per second)', ylabelp={'fontsize':20},
                          title='Linear approximations of the tuning curve', titlep={'fontsize':20})

# approximate fi curve
a = np.array([1.5, 5.])
for _a in a:
    fi_approx = taylor1_lif_fi(_a, u, tau_m, tref, xt)
    plot_continuous(u, fi_approx, plotp={'color':'r', 'linewidth':2}, ax=ax)
ax.plot(a, th_lif_fi(a, tau_m, tref, xt), 'ro')
ax.set_ylim(0., 1.5*fi[-1]);

# %% [markdown]
# The approximation improves with higher firing rates.
